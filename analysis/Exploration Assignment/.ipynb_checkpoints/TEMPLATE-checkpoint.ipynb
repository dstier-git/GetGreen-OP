# %% [markdown]
# # IMPORTANT!!!
# Duplicate this notebook and rename it as YourName-Exploration
#
# **DO NOT EDIT THE OG TEMPLATE FILE**

# %%
# From now on, we'll use this this cell to import our data
# Copy/paste in whatever notebook

import os
import pandas as pd

# Creates string for your specific path
# If using a different csv, replace the last argument ("Data-Sample.csv")
file_path = os.path.join(os.path.expanduser("~"), "Desktop", "GetGreen-OP", "data", "Data-Sample.csv")
df = pd.read_csv(file_path)
df.head() # preview
# Out:
# /var/folders/36/n9_s14992mn_bgl0d4wp2bb00000gn/T/ipykernel_5707/2152220176.py:10: DtypeWarning: Columns (86,87,88,89,92,93,94,95,100,101,102,103,104,105,106,107,114,115,116,117,118) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#                  name           time  sampling_factor    dataset  \
# 0  Application Opened  1746979256000                1  $mixpanel
# 1        Email Opened  1748520684000                1  $mixpanel
# 2        Email Opened  1748521346000                1  $mixpanel
# 3        Email Opened  1748521987000                1  $mixpanel
# 4        Email Opened  1748522139000                1  $mixpanel
#
#    properties.$app_build_number properties.$app_name  \
# 0                           2.0             GetGreen
# 1                           NaN                  NaN
# 2                           NaN                  NaN
# 3                           NaN                  NaN
# ...

# %% [markdown]
# # Task: pick important columns
# The loop below will iterate through all of the column names. Access data of a column with df[column_name], then use methods like: .head(), .unique(), .count(), .dropna() or anything else and pick the columns you think are worth keeping.

# %%
# Loops through all of the column names
for column in df.columns:    
    print("This column name:", column) # column is a string of this column's name
    
    # write your own code here
# Out:
# This column name: name
# This column name: time
# This column name: sampling_factor
# This column name: dataset
# This column name: properties.$app_build_number
# This column name: properties.$app_name
# This column name: properties.$app_namespace
# This column name: properties.$app_version_string
# This column name: properties.$carrier
# This column name: properties.$cellular_enabled
# This column name: properties.$city
# This column name: properties.$device
# This column name: properties.$device_name
# This column name: properties.$device_type
# This column name: properties.$import
# This column name: properties.$insert_id
# This column name: properties.$lib_version
# This column name: properties.$locale
# This column name: properties.$manufacturer
# This column name: properties.$model
# This column name: properties.$mp_api_endpoint
# This column name: properties.$mp_api_timestamp_ms
# This column name: properties.$os
# This column name: properties.$os_version
# ...

# %% [markdown]
# # Results
# Based on your results, manually **add your columns** to this list:

# %%
# Repace "..." with your column names as **strings** separated by commas
columns_list = [...]

print(columns_list)
# Out:
# [Ellipsis]

# %%
# This will error if your list is empty or has misspelled strings
df_selected = df[columns_list]
df_selected.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 2
#       1 # This will error if your list is empty or has misspelled strings
# ----> 2 df_selected = df[columns_list]
#       3 df_selected.head()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
# ...
